# %% [markdown]
# Libraries and Modules
#
# 1. Import module_name
#
# 2. from module_name import method_name1,mn2
#
# 3. import module as mallias name

# %% [markdown]
# University
#
#     |-Students.py
#
#     |   |-StudentDetails.py
#
#
#     |   |-StudentPerfirmance.py
#
#     |-Faculty.py
#
#     |   |-f_details.py
#
#     |   |-f_performance.py
#
#     |   |-f_feedback.py
#
#     |-Admission.py
#
#         |-Incomming.py
#
#         |-Outgoing.py
