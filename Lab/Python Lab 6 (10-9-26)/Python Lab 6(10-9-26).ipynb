# %%
#Senario
def box_print(S,n,m):
    for i in range(n):
        if i==0 or i==n-1:
            print(f"{S}"*n)
        else:
            print(f"{S} "+" "*(n-2)+f"{S}")
try:
    S=input("Enter the symbol:")
    n=int(input("Enter number of column:"))
    m=int(input("Enter number of rows:"))
    if len(S)!=1:
        raise Exception("Symbol must be single character")
    if n<2:
        raise Exception("Width must be greater than 2")
    if m<2:
        raise Exception("Height must be greater than 2")
    else:
        box_print(S,n,m)
    
except Exception as er:
    print('An exception happened: '+str(er))
# Out:
# An exception happened: Symbol must be single character

# %% [markdown]
# Taceback(Debugging technique)

# %%
#Logging with factorial
import logging
logging.basicConfig(level=logging.DEBUG,format='%(asctime)s -%(levelname)s -%(message)s')
logging.debug('Start program')

def fact(n):
    logging.debug("Start of factorial(%s)"%(n))
    total=1
    for i in range(1,n+1):
        total *=i
        logging.debug('i is '+str(i)+ ', total is '+str(total))
    logging.debug("End of factorial(%s)"%(n))
    return total

print(fact(5))
# Out:
# 2026-09-10 17:32:15,817 -DEBUG -Start program
# 2026-09-10 17:32:15,822 -DEBUG -Start of factorial(5)
# 2026-09-10 17:32:15,823 -DEBUG -i is 1, total is 1
# 2026-09-10 17:32:15,824 -DEBUG -i is 2, total is 2
# 2026-09-10 17:32:15,824 -DEBUG -i is 3, total is 6
# 2026-09-10 17:32:15,824 -DEBUG -i is 4, total is 24
# 2026-09-10 17:32:15,824 -DEBUG -i is 5, total is 120
# 2026-09-10 17:32:15,824 -DEBUG -End of factorial(5)
# 120

# %%
#Logging to a File
#Logging with factorial
import logging
import os
print("Current folder:",os.getcwd())
logging.basicConfig(filename="MyProgramLog.txt",level=logging.DEBUG,format='%(asctime)s -%(levelname)s -%(message)s',force=True)
logging.debug('Start program')

def fact(n):
    logging.debug("Start of factorial(%s)"%(n))
    total=1
    for i in range(1,n+1):
        total *=i
        logging.debug('i is '+str(i)+ ', total is '+str(total))
    logging.debug("End of factorial(%s)"%(n))
    return total

print(fact(5))
# Out:
# Current folder: c:\Python Lab\Python Lab 6 (10-9-26)
# 120

# %%
#Disabling logging
import logging
logging.disable

# %% [markdown]
# breakpoint then oop

# %% [markdown]
# # Object Oriented Programming(OOP)
# - data->attributes/variables
# - behavior->methods/function

# %%
class smartlamp:
    brand="Philips"
    power=12

lamp1=smartlamp()
print("Lamp brand:"+lamp1.brand)
print("Lamp power:",lamp1.power)
# Out:
# Lamp brand:Philips
# Lamp power: 12

# %% [markdown]
# Types of contructors:
# - default
# - parameterized
# - non-parameterized
